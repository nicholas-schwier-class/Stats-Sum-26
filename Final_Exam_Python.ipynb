# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Stats-Sum-26/blob/main/Final_Exam_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using the Iris.csv dataset from github repo peform the following:
#
# You have a experimental hypothesis that different species of iris plants will have different lengths of sepal length and width and pedal length and width.
#
# Write python code that checks for each for dimensions using ANOVA to compare the three species. Peform a post hoc test to check which species is statistically different and then reject or fail to reject your null hypothesis.
#
# Create bar graphs with standard error bars for each dimension including all three species

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
